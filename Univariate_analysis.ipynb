# %%
import pandas as pd
import os
print(os.path.abspath('../'))
# set the path where you have downloaded the data files
file_path = os.path.abspath('../session 2')
print(file_path)
train = pd.read_csv(file_path+'/train_income_data_AAII.csv')
test = pd.read_csv(file_path+'/test_income_data_AAII.csv')
# For windows, if the above paths doesn't works
# import os
# f_path = os.path.join(*['C:', 'Users', 'user', 'Desktop', 'train_income_data_AAII.csv'])
# train = pd.read_csv(f_path)
# or maybe try following to reach to the path
# absolute_path = os.path.abspath(os.path.dirname('train_income_data_AAII.csv'))
# Out:
# C:\Users\majid\Desktop\Karachi.AI DATA ANALYST\Python\
# C:\Users\majid\Desktop\Karachi.AI DATA ANALYST\Python\session 2

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.head()
# Out:
#    ID  Age         Workclass  Education      Marital.Status  \
# 0   1   39         State-gov  Bachelors       Never-married
# 1   2   50  Self-emp-not-inc  Bachelors  Married-civ-spouse
# 2   3   38           Private    HS-grad            Divorced
# 3   4   53           Private       11th  Married-civ-spouse
# 4   5   28           Private  Bachelors  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours.Per.Week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Black    Male              40
# 4     Prof-specialty           Wife  Black  Female              40
#
#   Native.Country Income.Group
# 0  United-States        <=50K
# 1  United-States        <=50K
# 2  United-States        <=50K
# 3  United-States        <=50K
# 4           Cuba        <=50K

# %%
# Get dimensions of your data
train.shape
# Out:
# (32561, 12)

# %%
train.describe()
# Out:
#                  ID           Age  Hours.Per.Week
# count  32561.000000  32561.000000    32561.000000
# mean   16281.000000     38.581647       40.437456
# std     9399.695394     13.640433       12.347429
# min        1.000000     17.000000        1.000000
# 25%     8141.000000     28.000000       40.000000
# 50%    16281.000000     37.000000       40.000000
# 75%    24421.000000     48.000000       45.000000
# max    32561.000000     90.000000       99.000000

# %% [markdown]
# ## Continous Variable

# %%
train.dtypes
# Out:
# ID                 int64
# Age                int64
# Workclass         object
# Education         object
# Marital.Status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Hours.Per.Week     int64
# Native.Country    object
# Income.Group      object
# dtype: object

# %% [markdown]
# ## Categorical Variables

# %%
categorical_var = train.dtypes.loc[train.dtypes=='object'].index
print(categorical_var)
# Out:
# Index(['Workclass', 'Education', 'Marital.Status', 'Occupation',
#        'Relationship', 'Race', 'Sex', 'Native.Country', 'Income.Group'],
#       dtype='object')

# %%
#Number of Unique values in each column
train[categorical_var].apply(lambda x:len(x.unique()))
# Out:
# Workclass          9
# Education         16
# Marital.Status     7
# Occupation        15
# Relationship       6
# Race               5
# Sex                2
# Native.Country    42
# Income.Group       2
# dtype: int64

# %%
# What happened up there??

# %%
train['Workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
len(train['Workclass'].unique())
# Out:
# 9

# %%
# Here we can see that 6 variables have less than 10 unique values but others have 15 or more unique values which seem to be too high.
# Pandas dataframes have an inbuilt routine called value_counts which gives the count of each category.
# We'll take 2 examples here to perform univariate analysis.

# %%
# Print counts of each category
train['Race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: Race, dtype: int64

# %%
# Percentage of observations in each category:
train['Race'].value_counts()/train.shape[0]
# Out:
# White                 0.854274
# Black                 0.095943
# Asian-Pac-Islander    0.031909
# Amer-Indian-Eskimo    0.009551
# Other                 0.008323
# Name: Race, dtype: float64

# %%
# Here we observe that the top variable itself accounts for ~85% of observations and top 2 combined have ~95% of observations.
# You should keep these observations in mind.

# %%
len(train['Native.Country'].unique())
# Out:
# 42

# %%
train['Native.Country'].value_counts()/train.shape[0]
# Out:
# United-States                 0.895857
# Mexico                        0.019748
# Philippines                   0.006081
# Germany                       0.004207
# Canada                        0.003716
# Puerto-Rico                   0.003501
# El-Salvador                   0.003255
# India                         0.003071
# Cuba                          0.002918
# England                       0.002764
# Jamaica                       0.002488
# South                         0.002457
# China                         0.002303
# Italy                         0.002242
# Dominican-Republic            0.002150
# Vietnam                       0.002058
# Guatemala                     0.001966
# Japan                         0.001904
# Poland                        0.001843
# Columbia                      0.001812
# Taiwan                        0.001566
# Haiti                         0.001351
# Iran                          0.001321
# Portugal                      0.001136
# Nicaragua                     0.001044
# Peru                          0.000952
# Greece                        0.000891
# France                        0.000891
# Ecuador                       0.000860
# Ireland                       0.000737
# Hong                          0.000614
# Cambodia                      0.000584
# Trinadad&Tobago               0.000584
# Thailand                      0.000553
# Laos                          0.000553
# Yugoslavia                    0.000491
# Outlying-US(Guam-USVI-etc)    0.000430
# Honduras                      0.000399
# Hungary                       0.000399
# Scotland                      0.000369
# Holand-Netherlands            0.000031
# Name: Native.Country, dtype: float64

# %%
# Here we see that around 89.5 % of our training data belongs to United States

# %%
train.groupby('Sex')['Age'].mean()
# Out:
# Sex
# Female    36.858230
# Male      39.433547
# Name: Age, dtype: float64

# %%
df4 = train.groupby(['Sex','Race'])['Age'].mean()

# %%
df4
# Out:
# Sex     Race
# Female  Amer-Indian-Eskimo    37.117647
#         Asian-Pac-Islander    35.089595
#         Black                 37.854019
#         Other                 31.678899
#         White                 36.811618
# Male    Amer-Indian-Eskimo    37.208333
#         Asian-Pac-Islander    39.073593
#         Black                 37.682600
#         Other                 34.654321
#         White                 39.652498
# Name: Age, dtype: float64

# %%
train.sort_values(by='Age')
# Out:
#           ID  Age         Workclass     Education      Marital.Status  \
# 12318  12319   17           Private          11th       Never-married
# 6312    6313   17           Private          11th       Never-married
# 30927  30928   17           Private          11th       Never-married
# 12787  12788   17         Local-gov          11th       Never-married
# 25755  25756   17               NaN          11th       Never-married
# 14475  14476   17           Private          11th       Never-married
# 23394  23395   17           Private          10th       Never-married
# 12802  12803   17           Private          10th       Never-married
# 11925  11926   17           Private          10th       Never-married
# 28770  28771   17           Private       7th-8th       Never-married
# 29992  29993   17           Private          11th       Never-married
# 30402  30403   17               NaN          11th       Never-married
# 27350  27351   17               NaN          11th       Never-married
# 1478    1479   17           Private          11th       Never-married
# 15350  15351   17               NaN          10th       Never-married
# 14514  14515   17      Self-emp-inc          10th       Never-married
# 7451    7452   17           Private          11th       Never-married
# 25203  25204   17           Private          12th       Never-married
# 24861  24862   17           Private          10th       Never-married
# 10295  10296   17           Private          11th       Never-married
# 8352    8353   17           Private          11th       Never-married
# 28754  28755   17           Private          11th       Never-married
# 371      372   17           Private          11th       Never-married
# 15850  15851   17           Private          11th       Never-married
# 29982  29983   17           Private          10th       Never-married
# 22857  22858   17         Local-gov          12th       Never-married
# 6874    6875   17           Private          10th       Never-married
# 12838  12839   17           Private          12th       Never-married
# 10836  10837   17           Private          11th       Never-married
# 26088  26089   17           Private          11th       Never-married
# ...      ...  ...               ...           ...                 ...
# 4109    4110   90               NaN     Bachelors             Widowed
# 10545  10546   90           Private       HS-grad  Married-civ-spouse
# 12975  12976   90           Private          10th  Married-civ-spouse
# 5272    5273   90           Private           9th       Never-married
# 22220  22221   90           Private     Bachelors       Never-married
# 15356  15357   90           Private       HS-grad             Widowed
# 24238  24239   90               NaN       1st-4th             Widowed
# 2303    2304   90           Private  Some-college       Never-married
# 18277  18278   90           Private     Bachelors  Married-civ-spouse
# 20610  20611   90           Private       Masters  Married-civ-spouse
# 18725  18726   90         Local-gov       HS-grad  Married-civ-spouse
# 14159  14160   90         Local-gov    Assoc-acdm  Married-civ-spouse
# 8806    8807   90           Private   Prof-school  Married-civ-spouse
# 1040    1041   90           Private       HS-grad       Never-married
# 6624    6625   90           Private          11th  Married-civ-spouse
# 31696  31697   90               NaN       HS-grad  Married-civ-spouse
# 25303  25304   90               NaN       7th-8th           Separated
# 18413  18414   90           Private     Bachelors       Never-married
# 11512  11513   90           Private       HS-grad       Never-married
# 19212  19213   90           Private  Some-college            Divorced
# 8973    8974   90           Private     Bachelors  Married-civ-spouse
# 11731  11732   90               NaN       HS-grad             Widowed
# 28463  28464   90       Federal-gov       HS-grad  Married-civ-spouse
# 11996  11997   90           Private     Bachelors       Never-married
# 15892  15893   90           Private     Bachelors  Married-civ-spouse
# 24043  24044   90  Self-emp-not-inc       HS-grad       Never-married
# 32277  32278   90           Private       HS-grad             Widowed
# 5104    5105   90           Private  Some-college       Never-married
# 8963    8964   90               NaN       HS-grad             Widowed
# 10210  10211   90  Self-emp-not-inc  Some-college  Married-civ-spouse
#
#               Occupation    Relationship                Race     Sex  \
# 12318              Sales       Own-child               White  Female
# 6312               Sales       Own-child               White    Male
# 30927      Other-service       Own-child               Black    Male
# 12787       Adm-clerical       Own-child               White  Female
# 25755                NaN       Own-child               White    Male
# 14475              Sales       Own-child               Black  Female
# 23394      Other-service       Own-child               White  Female
# 12802              Sales  Other-relative               Black  Female
# 11925      Other-service       Own-child               White  Female
# 28770              Sales       Own-child               White    Male
# 29992              Sales       Own-child               White  Female
# 30402                NaN       Own-child               White  Female
# 27350                NaN       Own-child               Black  Female
# 1478        Adm-clerical       Own-child  Asian-Pac-Islander  Female
# 15350                NaN       Own-child               White  Female
# 14514       Craft-repair       Own-child               White    Male
# 7451               Sales       Own-child               White  Female
# 25203              Sales       Own-child               White  Female
# 24861      Other-service       Own-child               White    Male
# 10295      Other-service       Own-child               White  Female
# 8352               Sales       Own-child               White  Female
# 28754  Handlers-cleaners       Own-child               White    Male
# 371        Other-service       Own-child               White    Male
# 15850              Sales       Own-child               White    Male
# 29982      Other-service       Own-child               White  Female
# 22857       Adm-clerical       Own-child               White  Female
# 6874       Other-service       Own-child               White    Male
# 12838     Prof-specialty       Own-child               White    Male
# 10836      Other-service       Own-child               Black    Male
# 26088  Handlers-cleaners   Not-in-family               Black  Female
# ...                  ...             ...                 ...     ...
# 4109                 NaN  Other-relative               White  Female
# 10545       Craft-repair         Husband               White    Male
# 12975    Exec-managerial         Husband               White    Male
# 5272        Adm-clerical   Not-in-family               White  Female
# 22220     Prof-specialty   Not-in-family  Asian-Pac-Islander    Male
# 15356   Transport-moving       Unmarried               White    Male
# 24238                NaN   Not-in-family               Black  Female
# 2303       Other-service   Not-in-family  Asian-Pac-Islander    Male
# 18277              Sales         Husband               White    Male
# 20610     Prof-specialty            Wife               White  Female
# 18725      Other-service         Husband               White    Male
# 14159       Adm-clerical         Husband  Asian-Pac-Islander    Male
# 8806      Prof-specialty         Husband               White    Male
# 1040       Other-service   Not-in-family               White  Female
# 6624        Craft-repair         Husband               White    Male
# 31696                NaN         Husband               White    Male
# 25303                NaN   Not-in-family               White  Female
# 18413     Prof-specialty       Own-child               White  Female
# 11512      Other-service       Own-child               White  Female
# 19212              Sales       Unmarried               Black  Female
# 8973               Sales         Husband               White    Male
# 11731                NaN   Not-in-family               White    Male
# 28463       Craft-repair         Husband               White    Male
# 11996    Exec-managerial   Not-in-family               White    Male
# 15892    Exec-managerial            Wife               White  Female
# 24043    Exec-managerial   Not-in-family               White    Male
# 32277       Adm-clerical       Unmarried               White  Female
# 5104       Other-service   Not-in-family  Asian-Pac-Islander    Male
# 8963                 NaN   Not-in-family               White  Female
# 10210    Farming-fishing         Husband               White    Male
#
#        Hours.Per.Week Native.Country Income.Group
# 12318               8  United-States        <=50K
# 6312               15  United-States        <=50K
# 30927              17  United-States        <=50K
# 12787              15  United-States        <=50K
# 25755              10  United-States        <=50K
# 14475              30  United-States        <=50K
# 23394              15  United-States        <=50K
# 12802              12  United-States        <=50K
# 11925              20  United-States        <=50K
# 28770               8  United-States        <=50K
# 29992              20  United-States        <=50K
# 30402              30  United-States        <=50K
# 27350              20  United-States        <=50K
# 1478               24  United-States        <=50K
# 15350              17  United-States        <=50K
# 14514              40  United-States        <=50K
# 7451               20  United-States        <=50K
# 25203               6  United-States        <=50K
# 24861              18  United-States        <=50K
# 10295               7  United-States        <=50K
# 8352               30  United-States        <=50K
# 28754              16  United-States        <=50K
# 371                10  United-States        <=50K
# 15850              20  United-States        <=50K
# 29982              10  United-States        <=50K
# 22857              12  United-States        <=50K
# 6874               10         Canada        <=50K
# 12838               7  United-States        <=50K
# 10836              20  United-States        <=50K
# 26088              15  United-States        <=50K
# ...               ...            ...          ...
# 4109               10  United-States        <=50K
# 10545              50        Ecuador         >50K
# 12975              40  United-States        <=50K
# 5272               40  United-States        <=50K
# 22220              40  United-States        <=50K
# 15356              99  United-States        <=50K
# 24238              40  United-States        <=50K
# 2303               35  United-States        <=50K
# 18277              20            NaN        <=50K
# 20610              40  United-States         >50K
# 18725              40  United-States        <=50K
# 14159              20    Philippines        <=50K
# 8806               72  United-States         >50K
# 1040               40  United-States        <=50K
# 6624               40  United-States        <=50K
# 31696              40  United-States         >50K
# 25303              15  United-States        <=50K
# 18413              10  United-States        <=50K
# 11512              24  United-States        <=50K
# 19212              37  United-States        <=50K
# 8973               15  United-States         >50K
# 11731               4  United-States        <=50K
# 28463              30  United-States        <=50K
# 11996              55  United-States        <=50K
# 15892              40        England         >50K
# 24043              12  United-States        <=50K
# 32277              25  United-States        <=50K
# 5104               35  United-States        <=50K
# 8963               40  United-States        <=50K
# 10210              40  United-States        <=50K
#
# [32561 rows x 12 columns]

# %%
train.sort_values(by='Age',ascending=False)
# Out:
#           ID  Age         Workclass     Education      Marital.Status  \
# 5406    5407   90           Private       Masters       Never-married
# 6624    6625   90           Private          11th  Married-civ-spouse
# 20610  20611   90           Private       Masters  Married-civ-spouse
# 1040    1041   90           Private       HS-grad       Never-married
# 1935    1936   90           Private     Bachelors  Married-civ-spouse
# 32367  32368   90         Local-gov       7th-8th  Married-civ-spouse
# 18832  18833   90           Private       Masters       Never-married
# 18277  18278   90           Private     Bachelors  Married-civ-spouse
# 19212  19213   90           Private  Some-college            Divorced
# 25303  25304   90               NaN       7th-8th           Separated
# 28463  28464   90       Federal-gov       HS-grad  Married-civ-spouse
# 5272    5273   90           Private           9th       Never-married
# 18413  18414   90           Private     Bachelors       Never-married
# 14159  14160   90         Local-gov    Assoc-acdm  Married-civ-spouse
# 4109    4110   90               NaN     Bachelors             Widowed
# 31030  31031   90           Private       HS-grad  Married-civ-spouse
# 11512  11513   90           Private       HS-grad       Never-married
# 15356  15357   90           Private       HS-grad             Widowed
# 4070    4071   90           Private          11th       Never-married
# 2303    2304   90           Private  Some-college       Never-married
# 2891    2892   90           Private  Some-college           Separated
# 10210  10211   90  Self-emp-not-inc  Some-college  Married-civ-spouse
# 8963    8964   90               NaN       HS-grad             Widowed
# 8973    8974   90           Private     Bachelors  Married-civ-spouse
# 31696  31697   90               NaN       HS-grad  Married-civ-spouse
# 5104    5105   90           Private  Some-college       Never-married
# 6232    6233   90  Self-emp-not-inc     Bachelors  Married-civ-spouse
# 22220  22221   90           Private     Bachelors       Never-married
# 32277  32278   90           Private       HS-grad             Widowed
# 12975  12976   90           Private          10th  Married-civ-spouse
# ...      ...  ...               ...           ...                 ...
# 22857  22858   17         Local-gov          12th       Never-married
# 13807  13808   17           Private          11th       Never-married
# 11097  11098   17           Private          11th       Never-married
# 13812  13813   17           Private          10th       Never-married
# 29684  29685   17           Private          10th       Never-married
# 29673  29674   17           Private          11th       Never-married
# 19380  19381   17           Private          10th       Never-married
# 27502  27503   17           Private          11th       Never-married
# 25021  25022   17           Private          11th       Never-married
# 25024  25025   17           Private          11th       Never-married
# 7947    7948   17           Private          10th       Never-married
# 29764  29765   17           Private          11th       Never-married
# 19211  19212   17           Private          11th       Never-married
# 31864  31865   17           Private          12th       Never-married
# 2278    2279   17           Private          10th       Never-married
# 11084  11085   17           Private          10th       Never-married
# 19003  19004   17           Private          11th       Never-married
# 27350  27351   17               NaN          11th       Never-married
# 19134  19135   17               NaN          10th       Never-married
# 29810  29811   17           Private          11th       Never-married
# 22957  22958   17           Private          11th       Never-married
# 15850  15851   17           Private          11th       Never-married
# 29795  29796   17           Private          11th       Never-married
# 2381    2382   17           Private          11th       Never-married
# 19173  19174   17           Private          11th       Never-married
# 609      610   17           Private          10th       Never-married
# 22928  22929   17               NaN          10th       Never-married
# 19190  19191   17           Private          12th       Never-married
# 19206  19207   17           Private          10th       Never-married
# 24954  24955   17           Private          11th       Never-married
#
#               Occupation    Relationship                Race     Sex  \
# 5406     Exec-managerial   Not-in-family               Black    Male
# 6624        Craft-repair         Husband               White    Male
# 20610     Prof-specialty            Wife               White  Female
# 1040       Other-service   Not-in-family               White  Female
# 1935     Exec-managerial         Husband               White    Male
# 32367    Protective-serv         Husband               White    Male
# 18832    Exec-managerial       Own-child               White  Female
# 18277              Sales         Husband               White    Male
# 19212              Sales       Unmarried               Black  Female
# 25303                NaN   Not-in-family               White  Female
# 28463       Craft-repair         Husband               White    Male
# 5272        Adm-clerical   Not-in-family               White  Female
# 18413     Prof-specialty       Own-child               White  Female
# 14159       Adm-clerical         Husband  Asian-Pac-Islander    Male
# 4109                 NaN  Other-relative               White  Female
# 31030  Machine-op-inspct         Husband               White    Male
# 11512      Other-service       Own-child               White  Female
# 15356   Transport-moving       Unmarried               White    Male
# 4070   Handlers-cleaners       Own-child               White    Male
# 2303       Other-service   Not-in-family  Asian-Pac-Islander    Male
# 2891        Adm-clerical       Own-child               White  Female
# 10210    Farming-fishing         Husband               White    Male
# 8963                 NaN   Not-in-family               White  Female
# 8973               Sales         Husband               White    Male
# 31696                NaN         Husband               White    Male
# 5104       Other-service   Not-in-family  Asian-Pac-Islander    Male
# 6232      Prof-specialty         Husband               White    Male
# 22220     Prof-specialty   Not-in-family  Asian-Pac-Islander    Male
# 32277       Adm-clerical       Unmarried               White  Female
# 12975    Exec-managerial         Husband               White    Male
# ...                  ...             ...                 ...     ...
# 22857       Adm-clerical       Own-child               White  Female
# 13807              Sales       Own-child               White  Female
# 11097  Handlers-cleaners       Own-child               White    Male
# 13812              Sales       Own-child               White    Male
# 29684      Other-service       Own-child               White    Male
# 29673      Other-service       Own-child               White  Female
# 19380      Other-service       Own-child               White    Male
# 27502  Handlers-cleaners       Own-child               White    Male
# 25021       Craft-repair       Own-child               White    Male
# 25024      Other-service   Not-in-family               White    Male
# 7947        Tech-support       Own-child               White    Male
# 29764      Other-service       Own-child               White  Female
# 19211      Other-service       Own-child               White    Male
# 31864       Adm-clerical       Own-child               White  Female
# 2278               Sales  Other-relative               White  Female
# 11084      Other-service   Not-in-family               White    Male
# 19003       Adm-clerical  Other-relative               White  Female
# 27350                NaN       Own-child               Black  Female
# 19134                NaN       Own-child               White  Female
# 29810  Handlers-cleaners       Own-child               White    Male
# 22957       Adm-clerical       Own-child               White  Female
# 15850              Sales       Own-child               White    Male
# 29795      Other-service  Other-relative               White  Female
# 2381        Craft-repair       Own-child               White    Male
# 19173      Other-service       Own-child               White    Male
# 609        Other-service       Own-child               White  Female
# 22928                NaN       Own-child               White  Female
# 19190  Handlers-cleaners       Own-child               White    Male
# 19206      Other-service       Own-child               White  Female
# 24954       Adm-clerical       Own-child               White    Male
#
#        Hours.Per.Week Native.Country Income.Group
# 5406               50  United-States         >50K
# 6624               40  United-States        <=50K
# 20610              40  United-States         >50K
# 1040               40  United-States        <=50K
# 1935               45  United-States        <=50K
# 32367              40  United-States        <=50K
# 18832              40  United-States        <=50K
# 18277              20            NaN        <=50K
# 19212              37  United-States        <=50K
# 25303              15  United-States        <=50K
# 28463              30  United-States        <=50K
# 5272               40  United-States        <=50K
# 18413              10  United-States        <=50K
# 14159              20    Philippines        <=50K
# 4109               10  United-States        <=50K
# 31030              40  United-States        <=50K
# 11512              24  United-States        <=50K
# 15356              99  United-States        <=50K
# 4070               40  United-States        <=50K
# 2303               35  United-States        <=50K
# 2891               40    Puerto-Rico        <=50K
# 10210              40  United-States        <=50K
# 8963               40  United-States        <=50K
# 8973               15  United-States         >50K
# 31696              40  United-States         >50K
# 5104               35  United-States        <=50K
# 6232               50  United-States        <=50K
# 22220              40  United-States        <=50K
# 32277              25  United-States        <=50K
# 12975              40  United-States        <=50K
# ...               ...            ...          ...
# 22857              12  United-States        <=50K
# 13807              15  United-States        <=50K
# 11097              25  United-States        <=50K
# 13812               5  United-States        <=50K
# 29684              20  United-States        <=50K
# 29673              15  United-States        <=50K
# 19380              15  United-States        <=50K
# 27502              15  United-States        <=50K
# 25021              20  United-States        <=50K
# 25024              20  United-States        <=50K
# 7947               10  United-States        <=50K
# 29764              20  United-States        <=50K
# 19211              15  United-States        <=50K
# 31864              25  United-States        <=50K
# 2278               10  United-States        <=50K
# 11084              20    El-Salvador        <=50K
# 19003              10  United-States        <=50K
# 27350              20  United-States        <=50K
# 19134              40  United-States        <=50K
# 29810              10  United-States        <=50K
# 22957              20  United-States        <=50K
# 15850              20  United-States        <=50K
# 29795              20  United-States        <=50K
# 2381               10  United-States        <=50K
# 19173              20  United-States        <=50K
# 609                21  United-States        <=50K
# 22928               4  United-States        <=50K
# 19190              15  United-States        <=50K
# 19206              25  United-States        <=50K
# 24954              16  United-States        <=50K
#
# [32561 rows x 12 columns]

# %%
train.sort_values(by=['Age','Hours.Per.Week'],ascending=False)
# Out:
#           ID  Age         Workclass     Education      Marital.Status  \
# 15356  15357   90           Private       HS-grad             Widowed
# 8806    8807   90           Private   Prof-school  Married-civ-spouse
# 5370    5371   90         Local-gov       Masters  Married-civ-spouse
# 11996  11997   90           Private     Bachelors       Never-married
# 5406    5407   90           Private       Masters       Never-married
# 6232    6233   90  Self-emp-not-inc     Bachelors  Married-civ-spouse
# 10545  10546   90           Private       HS-grad  Married-civ-spouse
# 1935    1936   90           Private     Bachelors  Married-civ-spouse
# 222      223   90           Private       HS-grad       Never-married
# 1040    1041   90           Private       HS-grad       Never-married
# 2891    2892   90           Private  Some-college           Separated
# 4070    4071   90           Private          11th       Never-married
# 5272    5273   90           Private           9th       Never-married
# 6624    6625   90           Private          11th  Married-civ-spouse
# 8963    8964   90               NaN       HS-grad             Widowed
# 10210  10211   90  Self-emp-not-inc  Some-college  Married-civ-spouse
# 12975  12976   90           Private          10th  Married-civ-spouse
# 15892  15893   90           Private     Bachelors  Married-civ-spouse
# 18725  18726   90         Local-gov       HS-grad  Married-civ-spouse
# 18832  18833   90           Private       Masters       Never-married
# 19489  19490   90           Private       HS-grad  Married-civ-spouse
# 19747  19748   90           Private       7th-8th  Married-civ-spouse
# 20610  20611   90           Private       Masters  Married-civ-spouse
# 22220  22221   90           Private     Bachelors       Never-married
# 24238  24239   90               NaN       1st-4th             Widowed
# 31030  31031   90           Private       HS-grad  Married-civ-spouse
# 31696  31697   90               NaN       HS-grad  Married-civ-spouse
# 32367  32368   90         Local-gov       7th-8th  Married-civ-spouse
# 19212  19213   90           Private  Some-college            Divorced
# 2303    2304   90           Private  Some-college       Never-married
# ...      ...  ...               ...           ...                 ...
# 1519    1520   17         Local-gov           9th       Never-married
# 10180  10181   17           Private          11th       Never-married
# 22496  22497   17           Private          11th       Never-married
# 2908    2909   17           Private          12th       Never-married
# 6542    6543   17               NaN          11th       Never-married
# 9655    9656   17           Private          10th       Never-married
# 12318  12319   17           Private          11th       Never-married
# 12409  12410   17           Private          11th       Never-married
# 12981  12982   17               NaN          10th       Never-married
# 19788  19789   17               NaN          11th       Never-married
# 20267  20268   17           Private          11th       Never-married
# 22423  22424   17           Private          10th       Never-married
# 28517  28518   17           Private          11th       Never-married
# 28770  28771   17           Private       7th-8th       Never-married
# 30209  30210   17               NaN          11th       Never-married
# 10295  10296   17           Private          11th       Never-married
# 12838  12839   17           Private          12th       Never-married
# 476      477   17           Private           9th       Never-married
# 9803    9804   17           Private          10th       Never-married
# 16131  16132   17           Private          12th       Never-married
# 23544  23545   17               NaN          10th       Never-married
# 25203  25204   17           Private          12th       Never-married
# 449      450   17               NaN          11th       Never-married
# 1389    1390   17           Private          11th       Never-married
# 13812  13813   17           Private          10th       Never-married
# 26864  26865   17           Private          11th       Never-married
# 29226  29227   17           Private          10th       Never-married
# 31131  31132   17           Private          11th       Never-married
# 9821    9822   17      Self-emp-inc          10th       Never-married
# 22928  22929   17               NaN          10th       Never-married
#
#               Occupation    Relationship                Race     Sex  \
# 15356   Transport-moving       Unmarried               White    Male
# 8806      Prof-specialty         Husband               White    Male
# 5370     Exec-managerial         Husband               White    Male
# 11996    Exec-managerial   Not-in-family               White    Male
# 5406     Exec-managerial   Not-in-family               Black    Male
# 6232      Prof-specialty         Husband               White    Male
# 10545       Craft-repair         Husband               White    Male
# 1935     Exec-managerial         Husband               White    Male
# 222        Other-service   Not-in-family               Black    Male
# 1040       Other-service   Not-in-family               White  Female
# 2891        Adm-clerical       Own-child               White  Female
# 4070   Handlers-cleaners       Own-child               White    Male
# 5272        Adm-clerical   Not-in-family               White  Female
# 6624        Craft-repair         Husband               White    Male
# 8963                 NaN   Not-in-family               White  Female
# 10210    Farming-fishing         Husband               White    Male
# 12975    Exec-managerial         Husband               White    Male
# 15892    Exec-managerial            Wife               White  Female
# 18725      Other-service         Husband               White    Male
# 18832    Exec-managerial       Own-child               White  Female
# 19489  Machine-op-inspct         Husband               White    Male
# 19747  Machine-op-inspct         Husband               White    Male
# 20610     Prof-specialty            Wife               White  Female
# 22220     Prof-specialty   Not-in-family  Asian-Pac-Islander    Male
# 24238                NaN   Not-in-family               Black  Female
# 31030  Machine-op-inspct         Husband               White    Male
# 31696                NaN         Husband               White    Male
# 32367    Protective-serv         Husband               White    Male
# 19212              Sales       Unmarried               Black  Female
# 2303       Other-service   Not-in-family  Asian-Pac-Islander    Male
# ...                  ...             ...                 ...     ...
# 1519       Other-service       Own-child               Black    Male
# 10180    Priv-house-serv       Own-child               White  Female
# 22496              Sales       Own-child               White  Female
# 2908       Other-service       Own-child               White  Female
# 6542                 NaN       Own-child               White  Female
# 9655       Other-service       Own-child               White    Male
# 12318              Sales       Own-child               White  Female
# 12409              Sales       Own-child               White  Female
# 12981                NaN       Own-child               White    Male
# 19788                NaN       Own-child               White  Female
# 20267              Sales       Own-child               White  Female
# 22423      Other-service       Own-child               White    Male
# 28517       Adm-clerical       Own-child               White  Female
# 28770              Sales       Own-child               White    Male
# 30209                NaN       Own-child               Black    Male
# 10295      Other-service       Own-child               White  Female
# 12838     Prof-specialty       Own-child               White    Male
# 476        Other-service   Not-in-family               White    Male
# 9803       Other-service       Own-child               White  Female
# 16131      Other-service       Own-child               White  Female
# 23544                NaN  Other-relative               White    Male
# 25203              Sales       Own-child               White  Female
# 449                  NaN       Own-child               White  Female
# 1389       Other-service       Own-child               White    Male
# 13812              Sales       Own-child               White    Male
# 26864      Other-service       Own-child               White  Female
# 29226              Sales       Own-child               White  Female
# 31131              Sales       Own-child               White    Male
# 9821       Other-service       Own-child               White    Male
# 22928                NaN       Own-child               White  Female
#
#        Hours.Per.Week Native.Country Income.Group
# 15356              99  United-States        <=50K
# 8806               72  United-States         >50K
# 5370               60  United-States         >50K
# 11996              55  United-States        <=50K
# 5406               50  United-States         >50K
# 6232               50  United-States        <=50K
# 10545              50        Ecuador         >50K
# 1935               45  United-States        <=50K
# 222                40  United-States        <=50K
# 1040               40  United-States        <=50K
# 2891               40    Puerto-Rico        <=50K
# 4070               40  United-States        <=50K
# 5272               40  United-States        <=50K
# 6624               40  United-States        <=50K
# 8963               40  United-States        <=50K
# 10210              40  United-States        <=50K
# 12975              40  United-States        <=50K
# 15892              40        England         >50K
# 18725              40  United-States        <=50K
# 18832              40  United-States        <=50K
# 19489              40  United-States        <=50K
# 19747              40  United-States        <=50K
# 20610              40  United-States         >50K
# 22220              40  United-States        <=50K
# 24238              40  United-States        <=50K
# 31030              40  United-States        <=50K
# 31696              40  United-States         >50K
# 32367              40  United-States        <=50K
# 19212              37  United-States        <=50K
# 2303               35  United-States        <=50K
# ...               ...            ...          ...
# 1519                9  United-States        <=50K
# 10180               9  United-States        <=50K
# 22496               9  United-States        <=50K
# 2908                8  United-States        <=50K
# 6542                8  United-States        <=50K
# 9655                8  United-States        <=50K
# 12318               8  United-States        <=50K
# 12409               8  United-States        <=50K
# 12981               8  United-States        <=50K
# 19788               8  United-States        <=50K
# 20267               8  United-States        <=50K
# 22423               8  United-States        <=50K
# 28517               8  United-States        <=50K
# 28770               8  United-States        <=50K
# 30209               8  United-States        <=50K
# 10295               7  United-States        <=50K
# 12838               7  United-States        <=50K
# 476                 6  United-States        <=50K
# 9803                6  United-States        <=50K
# 16131               6  United-States        <=50K
# 23544               6  United-States        <=50K
# 25203               6  United-States        <=50K
# 449                 5  United-States        <=50K
# 1389                5  United-States        <=50K
# 13812               5  United-States        <=50K
# 26864               5  United-States        <=50K
# 29226               5  United-States        <=50K
# 31131               5  United-States        <=50K
# 9821                4  United-States        <=50K
# 22928               4  United-States        <=50K
#
# [32561 rows x 12 columns]

# %%
train.head()
# Out:
#    ID  Age         Workclass  Education      Marital.Status  \
# 0   1   39         State-gov  Bachelors       Never-married
# 1   2   50  Self-emp-not-inc  Bachelors  Married-civ-spouse
# 2   3   38           Private    HS-grad            Divorced
# 3   4   53           Private       11th  Married-civ-spouse
# 4   5   28           Private  Bachelors  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours.Per.Week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Black    Male              40
# 4     Prof-specialty           Wife  Black  Female              40
#
#   Native.Country Income.Group
# 0  United-States        <=50K
# 1  United-States        <=50K
# 2  United-States        <=50K
# 3  United-States        <=50K
# 4           Cuba        <=50K

# %%
train.groupby(['Sex','Workclass'])['Age'].mean()
# Out:
# Sex     Workclass
# Female  Federal-gov         41.936508
#         Local-gov           41.729341
#         Never-worked        24.000000
#         Private             35.571336
#         Self-emp-inc        43.674074
#         Self-emp-not-inc    43.849624
#         State-gov           38.404908
#         Without-pay         58.600000
# Male    Federal-gov         42.910078
#         Local-gov           41.765501
#         Never-worked        19.200000
#         Private             37.433686
#         Self-emp-inc        46.339450
#         Self-emp-not-inc    45.178338
#         State-gov           40.059333
#         Without-pay         41.777778
# Name: Age, dtype: float64
